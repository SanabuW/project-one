# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
import numpy as np

Miles_df =("Avg mileage per state - Sheet1.csv")
Car_df = ("Top Cars in each state EV_Gasoline - Sheet1.csv")
Prices_df =("Avg Gas and Electric per state - Sheet1.csv")
Miles_df = pd.read_csv(Miles_df)
Car_df = pd.read_csv(Car_df)
Prices_df = pd.read_csv(Prices_df)

# %%
for name, dtype in Car_df.dtypes.iteritems():
    print(name, dtype)
# Out:
# States  object
# Regular object
# Electrical  object

# %%
Miles_df = Miles_df.rename(columns = {"Miles": "Avg Miles Driven per state"})
# Out:
#    State Registered Drivers Avg Miles Driven per state
# 0     AL          3,521,444                     16,054
# 1     AK            465,256                      9,915
# 2     AZ          3,433,995                     14,493
# 3     AR          1,947,867                     14,974
# 4     CA         21,243,939                     14,435
# 5     CO          3,107,258                     13,443
# 6     CT          2,652,593                     11,595
# 7     DE            556,688                     14,802
# 8     FL         12,853,428                     11,836
# 9     GA          5,550,176                     18,920
# 10    HI            769,383                     11,104
# 11    ID            883,546                     15,318
# 12    IL          7,961,046                     12,921
# 13    IN          3,976,241                     17,821
# 14    IA          1,952,508                     15,074
# 15    KS          1,908,117                     14,742
# 16    KY          2,694,469                     17,370
# 17    LA          2,759,120                     14,805
# 18    ME            920,235                     15,420
# 19    MD          3,382,451                     14,834
# 20    MA          4,489,695                     11,759
# 21    MI          6,925,246                     14,121
# 22    MN          2,940,789                     17,887
# 23    MS          2,007,746                     17,699
# 24    MO          3,856,271                     17,396
# 25    MT            678,899                     14,556
# 26    NE          1,195,219                     15,128
# 27    NV          1,370,643                     12,869
# 28    NH            929,630                     12,931
# 29    NJ          5,654,973                     11,927
# 30    NM          1,239,043                     18,369
# 31    NY         10,871,344                     11,871
# 32    NC          5,690,494                     15,729
# 33    ND            458,944                     15,725
# 34    OH          8,205,524                     12,906
# 35    OK          2,295,036                     18,891
# 36    OR          2,495,059                     14,032
# 37    PA          8,229,490                     12,435
# 38    RI            654,035                     12,781
# 39    SC          2,842,553                     16,020
# 40    SD            543,817                     15,505
# 41    TN          4,251,228                     15,462
# 42    TX         13,462,023                     16,347
# 43    UT          1,463,366                     15,442
# 44    VT            506,085                     13,458
# 45    VA          4,836,993                     15,464
# 46    WA          4,154,501                     12,837
# 47    WV          1,347,207                     14,283
# 48    WI          3,770,453                     15,188
# 49    WY            370,740                     21,821

# %%
combined_Car_df = pd.merge(Car_df, Miles_df, left_on= ["States "], right_on=["State"], how="outer")
combined_Car_df.head()
# Out:
#   States       Regular    Electrical  State Registered Drivers   Miles
# 0      AL     RAM 1500         BMW i8    AL          3,521,444  16,054
# 1      AK     RAM 1500  Tesla Model X    AK            465,256   9,915
# 2      AZ     RAM 1500  Tesla Model X    AZ          3,433,995  14,493
# 3      AR     RAM 1500         BMW i8    AR          1,947,867  14,974
# 4      CA  Honda Civic  Tesla Model S    CA         21,243,939  14,435

# %%
Prices_df = Prices_df.rename(columns = {"Regular": "Average Price per Gallon"})
Prices_df = Prices_df.rename(columns = {"Average EV per Gallon": "Average Price per Gallon EV"})

# %%
Combined_Car_df = pd.merge(combined_Car_df, Prices_df, how="outer", left_on="States ", right_on = "States")
Combined_Car_df.head()
# Out:
#   States     Regular_x    Electrical  State Registered Drivers   Miles States  \
# 0      AL     RAM 1500         BMW i8    AL          3,521,444  16,054     AL
# 1      AK     RAM 1500  Tesla Model X    AK            465,256   9,915     AK
# 2      AZ     RAM 1500  Tesla Model X    AZ          3,433,995  14,493     AZ
# 3      AR     RAM 1500         BMW i8    AR          1,947,867  14,974     AR
# 4      CA  Honda Civic  Tesla Model S    CA         21,243,939  14,435     CA
#
#   Regular_y Average EV per Gallon Saved per Gallon
# 0     $2.07                 $1.14            $0.93
# 1     $2.53                 $2.02            $0.51
# 2     $2.31                 $1.21            $1.10
# 3     $2.06                 $0.90            $1.16
# 4     $3.29                 $1.72            $1.57

# %%
Ev_Regualar_DF = ("Electric Vs Regular - Sheet1.csv")
Ev_Regualar_DF = pd.read_csv(Ev_Regualar_DF)
Ev_Regualar_DF.head()
# Out:
#                  Model 2020 quarter 2019 quarter  Change %     Types  \
# 0           Audi eTron        2,034        1,829      11.2  Electric
# 1               BMW i3          640        1,491     -57.1  Electric
# 2       Chevrolet Bolt        6,702        3,307     102.7  Electric
# 3  Chevrolet Silverado      179,443      163,311       9.9  Gasoline
# 4        Ford F-Series      198,338      233,952     -15.2    Diesel
#
#   List Pricing  Max Mileage   MPG  kWh/100 mi
# 0      $77,400          204   NaN        46.0
# 1      $44,450          153   NaN        30.0
# 2      $36,620          238   NaN        29.0
# 3      $48,485          450  20.0         NaN
# 4      $28,745          500  22.0         NaN

# %%
Ev_Regualar_DF['MPG'] = Ev_Regualar_DF['MPG'].fillna(0)
Ev_Regualar_DF['kWh/100 mi'] = Ev_Regualar_DF['kWh/100 mi'].fillna(0)
Ev_Regualar_DF
# Out:
#                   Model 2020 quarter 2019 quarter  Change %     Types  \
# 0            Audi eTron        2,034        1,829      11.2  Electric
# 1                BMW i3          640        1,491     -57.1  Electric
# 2        Chevrolet Bolt        6,702        3,307     102.7  Electric
# 3   Chevrolet Silverado      179,443      163,311       9.9  Gasoline
# 4         Ford F-Series      198,338      233,952     -15.2    Diesel
# 5            GMC Sierra       78,370       68,722      14.0   Regular
# 6           Honda Civic       60,284       70,166     -14.1   Regular
# 7            Honda CR-V       96,168      103,429      -7.0   Regular
# 8          Hyundai Kona          NaN          NaN       NaN  Electric
# 9         Hyundai Ioniq        4,331        5,428     -20.2  Electric
# 10          Nissan Leaf        4,635        3,254      42.4  Electric
# 11           Ram Pickup      161,266      172,579      -6.6   Regular
# 12        Tesla Model 3            0       47,275    -100.0  Electric
# 13        Tesla Model S            0        3,750    -100.0  Electric
# 14        Tesla Model X            0        5,500    -100.0  Electric
# 15        Tesla Model Y            0            0       0.0  Electric
# 16         Toyota Camry       89,403       78,522      13.9   Regular
# 17       Toyota Corolla       70,965       70,872       0.1   Regular
# 18          Toyota RAV4      127,813      123,446       3.5   Regular
# 19        Toyota Tacoma       75,187       61,179      22.9   Regular
#
#    List Pricing  Max Mileage   MPG  kWh/100 mi
# 0       $77,400          204   0.0        46.0
# 1       $44,450          153   0.0        30.0
# 2       $36,620          238   0.0        29.0
# 3       $48,485          450  20.0         0.0
# 4       $28,745          500  22.0         0.0
# 5       $44,000          440  17.0         0.0
# 6       $20,000          430  37.0         0.0
# 7       $25,150          406  31.0         0.0
# 8       $37,190          258   0.0        27.0
# 9       $33,045          193   0.0        25.0
# 10      $31,600          157   0.0        30.0
# 11      $32,154          560  22.0         0.0
# 12      $37,990          348   0.0        26.0
# 13      $74,990          379   0.0        30.0
# 14      $79,990          315   0.0        35.0
# 15      $49,900          314   0.0        28.0
# 16      $24,970          686  33.0         0.0
# 17      $19,600          488  35.0         0.0
# 18      $25,950          400  30.0         0.0
# 19      $26,050          380  20.0         0.0

# %%
Ev_Regualar_DF['Max Gallons'] = Ev_Regualar_DF['Max Mileage']/Ev_Regualar_DF['MPG']
Ev_Regualar_DF['Max EV kWh'] = Ev_Regualar_DF['Max Mileage']/(100/Ev_Regualar_DF['kWh/100 mi'])
Ev_Regualar_DF
# Out:
#                   Model 2020 quarter 2019 quarter  Change %     Types  \
# 0            Audi eTron        2,034        1,829      11.2  Electric
# 1                BMW i3          640        1,491     -57.1  Electric
# 2        Chevrolet Bolt        6,702        3,307     102.7  Electric
# 3   Chevrolet Silverado      179,443      163,311       9.9  Gasoline
# 4         Ford F-Series      198,338      233,952     -15.2    Diesel
# 5            GMC Sierra       78,370       68,722      14.0   Regular
# 6           Honda Civic       60,284       70,166     -14.1   Regular
# 7            Honda CR-V       96,168      103,429      -7.0   Regular
# 8          Hyundai Kona          NaN          NaN       NaN  Electric
# 9         Hyundai Ioniq        4,331        5,428     -20.2  Electric
# 10          Nissan Leaf        4,635        3,254      42.4  Electric
# 11           Ram Pickup      161,266      172,579      -6.6   Regular
# 12        Tesla Model 3            0       47,275    -100.0  Electric
# 13        Tesla Model S            0        3,750    -100.0  Electric
# 14        Tesla Model X            0        5,500    -100.0  Electric
# 15        Tesla Model Y            0            0       0.0  Electric
# 16         Toyota Camry       89,403       78,522      13.9   Regular
# 17       Toyota Corolla       70,965       70,872       0.1   Regular
# 18          Toyota RAV4      127,813      123,446       3.5   Regular
# 19        Toyota Tacoma       75,187       61,179      22.9   Regular
#
#    List Pricing  Max Mileage   MPG  kWh/100 mi  Max Gallons  Max EV kWh
# 0       $77,400          204   0.0        46.0          inf       93.84
# 1       $44,450          153   0.0        30.0          inf       45.90
# 2       $36,620          238   0.0        29.0          inf       69.02
# 3       $48,485          450  20.0         0.0    22.500000        0.00
# 4       $28,745          500  22.0         0.0    22.727273        0.00
# 5       $44,000          440  17.0         0.0    25.882353        0.00
# 6       $20,000          430  37.0         0.0    11.621622        0.00
# 7       $25,150          406  31.0         0.0    13.096774        0.00
# 8       $37,190          258   0.0        27.0          inf       69.66
# 9       $33,045          193   0.0        25.0          inf       48.25
# 10      $31,600          157   0.0        30.0          inf       47.10
# 11      $32,154          560  22.0         0.0    25.454545        0.00
# 12      $37,990          348   0.0        26.0          inf       90.48
# 13      $74,990          379   0.0        30.0          inf      113.70
# 14      $79,990          315   0.0        35.0          inf      110.25
# 15      $49,900          314   0.0        28.0          inf       87.92
# 16      $24,970          686  33.0         0.0    20.787879        0.00
# 17      $19,600          488  35.0         0.0    13.942857        0.00
# 18      $25,950          400  30.0         0.0    13.333333        0.00
# 19      $26,050          380  20.0         0.0    19.000000        0.00

# %%
New_Ev_Regualar_DF= Ev_Regualar_DF[['Model','Types','List Pricing','Max Mileage','MPG',
                                   'kWh/100 mi','Max Gallons','Max EV kWh']].copy()
New_Ev_Regualar_DF['Full Gasoline Price'] = New_Ev_Regualar_DF['Max Gallons'] * 3.29
New_Ev_Regualar_DF
# Out:
#                   Model     Types List Pricing  Max Mileage   MPG  kWh/100 mi  \
# 0            Audi eTron  Electric      $77,400          204   0.0        46.0
# 1                BMW i3  Electric      $44,450          153   0.0        30.0
# 2        Chevrolet Bolt  Electric      $36,620          238   0.0        29.0
# 3   Chevrolet Silverado  Gasoline      $48,485          450  20.0         0.0
# 4         Ford F-Series    Diesel      $28,745          500  22.0         0.0
# 5            GMC Sierra   Regular      $44,000          440  17.0         0.0
# 6           Honda Civic   Regular      $20,000          430  37.0         0.0
# 7            Honda CR-V   Regular      $25,150          406  31.0         0.0
# 8          Hyundai Kona  Electric      $37,190          258   0.0        27.0
# 9         Hyundai Ioniq  Electric      $33,045          193   0.0        25.0
# 10          Nissan Leaf  Electric      $31,600          157   0.0        30.0
# 11           Ram Pickup   Regular      $32,154          560  22.0         0.0
# 12        Tesla Model 3  Electric      $37,990          348   0.0        26.0
# 13        Tesla Model S  Electric      $74,990          379   0.0        30.0
# 14        Tesla Model X  Electric      $79,990          315   0.0        35.0
# 15        Tesla Model Y  Electric      $49,900          314   0.0        28.0
# 16         Toyota Camry   Regular      $24,970          686  33.0         0.0
# 17       Toyota Corolla   Regular      $19,600          488  35.0         0.0
# 18          Toyota RAV4   Regular      $25,950          400  30.0         0.0
# 19        Toyota Tacoma   Regular      $26,050          380  20.0         0.0
#
#     Max Gallons  Max EV kWh  Full Gasoline Price
# 0           inf       93.84                  inf
# 1           inf       45.90                  inf
# 2           inf       69.02                  inf
# 3     22.500000        0.00            74.025000
# 4     22.727273        0.00            74.772727
# 5     25.882353        0.00            85.152941
# 6     11.621622        0.00            38.235135
# 7     13.096774        0.00            43.088387
# 8           inf       69.66                  inf
# 9           inf       48.25                  inf
# 10          inf       47.10                  inf
# 11    25.454545        0.00            83.745455
# 12          inf       90.48                  inf
# 13          inf      113.70                  inf
# 14          inf      110.25                  inf
# 15          inf       87.92                  inf
# 16    20.787879        0.00            68.392121
# 17    13.942857        0.00            45.872000
# 18    13.333333        0.00            43.866667
# 19    19.000000        0.00            62.510000

# %%
Cali_Ev_Regular = New_Ev_Regualar_DF
Cali_Ev_Regular = Cali_Ev_Regular[~Cali_Ev_Regular.isin([np.inf])]
Cali_Ev_Regular['Max Gallons'].fillna(0, inplace=True)
Cali_Ev_Regular['Full Gasoline Price'].fillna(0, inplace=True)
Cali_Ev_Regular
# Out:
#                   Model     Types List Pricing  Max Mileage   MPG  kWh/100 mi  \
# 0            Audi eTron  Electric      $77,400          204   0.0        46.0
# 1                BMW i3  Electric      $44,450          153   0.0        30.0
# 2        Chevrolet Bolt  Electric      $36,620          238   0.0        29.0
# 3   Chevrolet Silverado  Gasoline      $48,485          450  20.0         0.0
# 4         Ford F-Series    Diesel      $28,745          500  22.0         0.0
# 5            GMC Sierra   Regular      $44,000          440  17.0         0.0
# 6           Honda Civic   Regular      $20,000          430  37.0         0.0
# 7            Honda CR-V   Regular      $25,150          406  31.0         0.0
# 8          Hyundai Kona  Electric      $37,190          258   0.0        27.0
# 9         Hyundai Ioniq  Electric      $33,045          193   0.0        25.0
# 10          Nissan Leaf  Electric      $31,600          157   0.0        30.0
# 11           Ram Pickup   Regular      $32,154          560  22.0         0.0
# 12        Tesla Model 3  Electric      $37,990          348   0.0        26.0
# 13        Tesla Model S  Electric      $74,990          379   0.0        30.0
# 14        Tesla Model X  Electric      $79,990          315   0.0        35.0
# 15        Tesla Model Y  Electric      $49,900          314   0.0        28.0
# 16         Toyota Camry   Regular      $24,970          686  33.0         0.0
# 17       Toyota Corolla   Regular      $19,600          488  35.0         0.0
# 18          Toyota RAV4   Regular      $25,950          400  30.0         0.0
# 19        Toyota Tacoma   Regular      $26,050          380  20.0         0.0
#
#     Max Gallons  Max EV kWh  Full Gasoline Price
# 0      0.000000       93.84             0.000000
# 1      0.000000       45.90             0.000000
# 2      0.000000       69.02             0.000000
# 3     22.500000        0.00            74.025000
# 4     22.727273        0.00            74.772727
# 5     25.882353        0.00            85.152941
# 6     11.621622        0.00            38.235135
# 7     13.096774        0.00            43.088387
# 8      0.000000       69.66             0.000000
# 9      0.000000       48.25             0.000000
# 10     0.000000       47.10             0.000000
# 11    25.454545        0.00            83.745455
# 12     0.000000       90.48             0.000000
# 13     0.000000      113.70             0.000000
# 14     0.000000      110.25             0.000000
# 15     0.000000       87.92             0.000000
# 16    20.787879        0.00            68.392121
# 17    13.942857        0.00            45.872000
# 18    13.333333        0.00            43.866667
# 19    19.000000        0.00            62.510000

# %%
Cali_Ev_Regular['Yearly_Gas_Price_Cali'] = (14435/ Cali_Ev_Regular['Max Mileage'])* (Cali_Ev_Regular['Full Gasoline Price'])
Cali_Ev_Regular
# Out:
#                   Model     Types List Pricing  Max Mileage   MPG  kWh/100 mi  \
# 0            Audi eTron  Electric      $77,400          204   0.0        46.0
# 1                BMW i3  Electric      $44,450          153   0.0        30.0
# 2        Chevrolet Bolt  Electric      $36,620          238   0.0        29.0
# 3   Chevrolet Silverado  Gasoline      $48,485          450  20.0         0.0
# 4         Ford F-Series    Diesel      $28,745          500  22.0         0.0
# 5            GMC Sierra   Regular      $44,000          440  17.0         0.0
# 6           Honda Civic   Regular      $20,000          430  37.0         0.0
# 7            Honda CR-V   Regular      $25,150          406  31.0         0.0
# 8          Hyundai Kona  Electric      $37,190          258   0.0        27.0
# 9         Hyundai Ioniq  Electric      $33,045          193   0.0        25.0
# 10          Nissan Leaf  Electric      $31,600          157   0.0        30.0
# 11           Ram Pickup   Regular      $32,154          560  22.0         0.0
# 12        Tesla Model 3  Electric      $37,990          348   0.0        26.0
# 13        Tesla Model S  Electric      $74,990          379   0.0        30.0
# 14        Tesla Model X  Electric      $79,990          315   0.0        35.0
# 15        Tesla Model Y  Electric      $49,900          314   0.0        28.0
# 16         Toyota Camry   Regular      $24,970          686  33.0         0.0
# 17       Toyota Corolla   Regular      $19,600          488  35.0         0.0
# 18          Toyota RAV4   Regular      $25,950          400  30.0         0.0
# 19        Toyota Tacoma   Regular      $26,050          380  20.0         0.0
#
#     Max Gallons  Max EV kWh  Full Gasoline Price  Yearly_Gas_Price_Cali
# 0      0.000000       93.84             0.000000               0.000000
# 1      0.000000       45.90             0.000000               0.000000
# 2      0.000000       69.02             0.000000               0.000000
# 3     22.500000        0.00            74.025000            2374.557500
# 4     22.727273        0.00            74.772727            2158.688636
# 5     25.882353        0.00            85.152941            2793.597059
# 6     11.621622        0.00            38.235135            1283.544595
# 7     13.096774        0.00            43.088387            1531.972581
# 8      0.000000       69.66             0.000000               0.000000
# 9      0.000000       48.25             0.000000               0.000000
# 10     0.000000       47.10             0.000000               0.000000
# 11    25.454545        0.00            83.745455            2158.688636
# 12     0.000000       90.48             0.000000               0.000000
# 13     0.000000      113.70             0.000000               0.000000
# 14     0.000000      110.25             0.000000               0.000000
# 15     0.000000       87.92             0.000000               0.000000
# 16    20.787879        0.00            68.392121            1439.125758
# 17    13.942857        0.00            45.872000            1356.890000
# 18    13.333333        0.00            43.866667            1583.038333
# 19    19.000000        0.00            62.510000            2374.557500

# %%
kWh_rate = ("kWh Rate per state - Sheet1.csv")
kWh_rate = pd.read_csv(kWh_rate)
kWh_rate.head()
# Out:
#   States  Avg kWh Rate
# 0     AL         21.79
# 1     AK         11.76
# 2     AZ          9.30
# 3     AR         12.12
# 4     CA         18.31

# %%
Cali_Ev_Regular['Yearly_EV_Price_Cali'] =((14435/Cali_Ev_Regular['Max Mileage'])*(Cali_Ev_Regular['Max EV kWh'] * .1831))
Cali_Ev_Regular
# Out:
#                   Model     Types List Pricing  Max Mileage   MPG  kWh/100 mi  \
# 0            Audi eTron  Electric      $77,400          204   0.0        46.0
# 1                BMW i3  Electric      $44,450          153   0.0        30.0
# 2        Chevrolet Bolt  Electric      $36,620          238   0.0        29.0
# 3   Chevrolet Silverado  Gasoline      $48,485          450  20.0         0.0
# 4         Ford F-Series    Diesel      $28,745          500  22.0         0.0
# 5            GMC Sierra   Regular      $44,000          440  17.0         0.0
# 6           Honda Civic   Regular      $20,000          430  37.0         0.0
# 7            Honda CR-V   Regular      $25,150          406  31.0         0.0
# 8          Hyundai Kona  Electric      $37,190          258   0.0        27.0
# 9         Hyundai Ioniq  Electric      $33,045          193   0.0        25.0
# 10          Nissan Leaf  Electric      $31,600          157   0.0        30.0
# 11           Ram Pickup   Regular      $32,154          560  22.0         0.0
# 12        Tesla Model 3  Electric      $37,990          348   0.0        26.0
# 13        Tesla Model S  Electric      $74,990          379   0.0        30.0
# 14        Tesla Model X  Electric      $79,990          315   0.0        35.0
# 15        Tesla Model Y  Electric      $49,900          314   0.0        28.0
# 16         Toyota Camry   Regular      $24,970          686  33.0         0.0
# 17       Toyota Corolla   Regular      $19,600          488  35.0         0.0
# 18          Toyota RAV4   Regular      $25,950          400  30.0         0.0
# 19        Toyota Tacoma   Regular      $26,050          380  20.0         0.0
#
#     Max Gallons  Max EV kWh  Full Gasoline Price  Yearly_Gas_Price_Cali  \
# 0      0.000000       93.84             0.000000               0.000000
# 1      0.000000       45.90             0.000000               0.000000
# 2      0.000000       69.02             0.000000               0.000000
# 3     22.500000        0.00            74.025000            2374.557500
# 4     22.727273        0.00            74.772727            2158.688636
# 5     25.882353        0.00            85.152941            2793.597059
# 6     11.621622        0.00            38.235135            1283.544595
# 7     13.096774        0.00            43.088387            1531.972581
# 8      0.000000       69.66             0.000000               0.000000
# 9      0.000000       48.25             0.000000               0.000000
# 10     0.000000       47.10             0.000000               0.000000
# 11    25.454545        0.00            83.745455            2158.688636
# 12     0.000000       90.48             0.000000               0.000000
# 13     0.000000      113.70             0.000000               0.000000
# 14     0.000000      110.25             0.000000               0.000000
# 15     0.000000       87.92             0.000000               0.000000
# 16    20.787879        0.00            68.392121            1439.125758
# 17    13.942857        0.00            45.872000            1356.890000
# 18    13.333333        0.00            43.866667            1583.038333
# 19    19.000000        0.00            62.510000            2374.557500
#
#     Yearly_EV_Price_Cali
# 0            1215.802310
# 1             792.914550
# 2             766.484065
# 3               0.000000
# 4               0.000000
# 5               0.000000
# 6               0.000000
# 7               0.000000
# 8             713.623095
# 9             660.762125
# 10            792.914550
# 11              0.000000
# 12            687.192610
# 13            792.914550
# 14            925.066975
# 15            740.053580
# 16              0.000000
# 17              0.000000
# 18              0.000000
# 19              0.000000

# %%
Cali_Ev_Regular.to_csv("Cali_Ev_Regular_Yearly_Price.csv")
