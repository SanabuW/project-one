# %%
'''
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)


'''

# %%
import requests
import json


api_key = "XzSNnJtfDK5IpktOiRC0ZE0n5I5jRh2UX6TEcURPglld794gH8y4vifAS6KaIp1LZnQFEq9sln52Soamph5Lk2v_IcztwvhLoohpjd1rXgqtIhk69shA63HRLMP8X3Yx"
headers = {"Authorization": "Bearer %s" % api_key}

# %%
url = "https://api.yelp.com/v3/businesses/search"

params = {"term": "izakaya", "location":"San Diego"}

requestObject = requests.get(url, params = params, headers = headers)
print('status code is {}'.format(requestObject.status_code))

#SHOW A PRETTY PRINT OF THIS
# Out:
# status code is 200

# %%
json.loads(requestObject.text)
# Out:
# {'businesses': [{'id': '1yhgFgMc_QTuayFjROHhCQ',
#    'alias': 'izakaya-masa-san-diego',
#    'name': 'Izakaya Masa',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/agDDRj2-A0gTO0KoomXh7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-masa-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 1226,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.75105, 'longitude': -117.17201},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '928 Fort Stockton Dr',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92103',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['928 Fort Stockton Dr', 'San Diego, CA 92103']},
#    'phone': '+16195421354',
#    'display_phone': '(619) 542-1354',
#    'distance': 4685.110433345481},
#   {'id': '7CjC7lj7bXvjPPRb_HqM3g',
#    'alias': 'ee-nami-tonkatsu-izakaya-san-diego',
#    'name': 'EE NAMI Tonkatsu Izakaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JH46r8CE2Qde0iAW1BLqAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ee-nami-tonkatsu-izakaya-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 138,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.835515, 'longitude': -117.189242},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '4706 Clairemont Mesa Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4706 Clairemont Mesa Blvd', 'San Diego, CA 92117']},
#    'phone': '+18582466903',
#    'display_phone': '(858) 246-6903',
#    'distance': 5977.992750190915},
#   {'id': '9ylUZ4hPyg7UVcZn6cp4gA',
#    'alias': 'wa-dining-okan-san-diego-2',
#    'name': 'Wa Dining OKAN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rRTBIyKfBFMCjc256dRfoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wa-dining-okan-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 1092,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.81423, 'longitude': -117.15385},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3860 Convoy St',
#     'address2': 'Ste 110',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3860 Convoy St', 'Ste 110', 'San Diego, CA 92111']},
#    'phone': '+18582790941',
#    'display_phone': '(858) 279-0941',
#    'distance': 2632.4154753728553},
#   {'id': 'p1sFpg2FuFM9dtO3oL4FOw',
#    'alias': 'izakaya-sakura-san-diego',
#    'name': 'Izakaya Sakura',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BKkBPXcsL2kV6qO2fxd43w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-sakura-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 682,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 32.8148792123313,
#     'longitude': -117.154941558838},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3904 Convoy St',
#     'address2': 'Ste 121',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92184',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3904 Convoy St', 'Ste 121', 'San Diego, CA 92184']},
#    'phone': '+18585696151',
#    'display_phone': '(858) 569-6151',
#    'distance': 2704.3154989003556},
#   {'id': '5IcovCryItzBBv7CMtaAsg',
#    'alias': 'tanuki-san-diego',
#    'name': 'Tanuki',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pOtfwYpxtG7ItQrHe_RO_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tanuki-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 218,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.76298, 'longitude': -117.10509},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4191 Adams Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4191 Adams Ave', 'San Diego, CA 92116']},
#    'phone': '+16196240592',
#    'display_phone': '(619) 624-0592',
#    'distance': 5512.868758348218},
#   {'id': '-puDFMMdediMnHeqDbvbBg',
#    'alias': 'tajima-mercury-san-diego-6',
#    'name': 'Tajima Mercury',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eWJ1WO0Jawpn2PY3wWd-iQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tajima-mercury-san-diego-6?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 1844,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8203377294774,
#     'longitude': -117.148647939951},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4411 Mercury St',
#     'address2': 'Ste 110',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4411 Mercury St', 'Ste 110', 'San Diego, CA 92111']},
#    'phone': '+18582785367',
#    'display_phone': '(858) 278-5367',
#    'distance': 3348.8371207288933},
#   {'id': 'jl4sx_VhdObAQgRrNb458g',
#    'alias': 'yokohama-yakitori-koubou-san-diego-2',
#    'name': 'Yokohama Yakitori Koubou',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VjalaIyYf9PatxEHJlMAww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yokohama-yakitori-koubou-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 678,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.81486, 'longitude': -117.15462},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '3904 Convoy St',
#     'address2': 'Ste 108',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3904 Convoy St', 'Ste 108', 'San Diego, CA 92111']},
#    'phone': '+18582778822',
#    'display_phone': '(858) 277-8822',
#    'distance': 2653.779398588172},
#   {'id': 'iYWVq9O_wVQSdpPiXclomw',
#    'alias': 'fusion-izakaya-52-san-diego',
#    'name': 'Fusion Izakaya 52',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4AwG4JucTqwHfrLsGPL3Qg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fusion-izakaya-52-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 262,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8194510512788,
#     'longitude': -117.154364437989},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4367 Convoy St',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4367 Convoy St', 'San Diego, CA 92111']},
#    'phone': '+18584306689',
#    'display_phone': '(858) 430-6689',
#    'distance': 3211.5976654947744},
#   {'id': '_T88LJN8whEPe6uovSsb0g',
#    'alias': 'yakyudori-san-diego',
#    'name': 'Yakyudori',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SPSDwk1DKo6jziObFtwBWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakyudori-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 1960,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8305462783919,
#     'longitude': -117.153696253781},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4898 Convoy St',
#     'address2': 'Ste 101',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4898 Convoy St', 'Ste 101', 'San Diego, CA 92111']},
#    'phone': '+18582682888',
#    'display_phone': '(858) 268-2888',
#    'distance': 4445.368866139292},
#   {'id': 'jchAs_r0UQlrvw43mm5EcA',
#    'alias': 'izakaya-naruto-chula-vista',
#    'name': 'Izakaya Naruto',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nB8-reHhVzuXDOB7ZeQddw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-naruto-chula-vista?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 769,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.6094521359027,
#     'longitude': -117.067828749738},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '1216 3rd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chula Vista',
#     'zip_code': '91911',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1216 3rd Ave', 'Chula Vista, CA 91911']},
#    'phone': '+16198822880',
#    'display_phone': '(619) 882-2880',
#    'distance': 21696.35459860056},
#   {'id': 'MSK605T_kipDGhx0VMmaZA',
#    'alias': 'yakitori-taisho-san-diego',
#    'name': 'Yakitori Taisho',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wamZuDUKeb6lffvW7cyPiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yakitori-taisho-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 317,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.83371, 'longitude': -117.1794},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5185 Clairemont Mesa Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5185 Clairemont Mesa Blvd', 'San Diego, CA 92117']},
#    'phone': '+18587520468',
#    'display_phone': '(858) 752-0468',
#    'distance': 5372.805977565743},
#   {'id': 'L2rcFMJJK7bn9TlSePPOxg',
#    'alias': 'ikiru-japanese-san-diego',
#    'name': 'Ikiru Japanese',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DoGDyoHwSAVovZHLN9Ahew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ikiru-japanese-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 867,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.7358915, 'longitude': -117.2173427},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2850 Womble Rd',
#     'address2': 'Ste 105',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92106',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2850 Womble Rd', 'Ste 105', 'San Diego, CA 92106']},
#    'phone': '+16192211228',
#    'display_phone': '(619) 221-1228',
#    'distance': 8457.98662683172},
#   {'id': 'fmk13zHLXQ8gtPOVkVGB6w',
#    'alias': 'kokoro-restaurant-san-diego-2',
#    'name': 'Kokoro Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2DqNqBrqMV8mU5mJaIOw4A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kokoro-restaurant-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 232,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.8028335, 'longitude': -117.139202},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3298 Greyling Dr',
#     'address2': 'Ste B',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['3298 Greyling Dr', 'Ste B', 'San Diego, CA 92123']},
#    'phone': '+18585654113',
#    'display_phone': '(858) 565-4113',
#    'distance': 1947.9319171154189},
#   {'id': 'juqZAOcQ2ieFEoMhu0l40g',
#    'alias': 'okan-diner-san-diego',
#    'name': 'Okan Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZdyqHH0PK2f7WjdHOpBpug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okan-diner-san-diego?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 311,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.83462, 'longitude': -117.17449},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5430 Clairemont Mesa Blvd',
#     'address2': 'Ste G',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92117',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5430 Clairemont Mesa Blvd',
#      'Ste G',
#      'San Diego, CA 92117']},
#    'phone': '+18582784228',
#    'display_phone': '(858) 278-4228',
#    'distance': 5287.086332807596},
#   {'id': 'rvKODj_feRX-Ti0LyKSNcg',
#    'alias': 'robataya-oton-san-diego-2',
#    'name': 'Robataya Oton',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CODQwzrMxoEqoVjMHI7vQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/robataya-oton-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 321,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.832705, 'longitude': -117.138334},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '5447 Kearny Villa Rd',
#     'address2': 'Ste D',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92123',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['5447 Kearny Villa Rd',
#      'Ste D',
#      'San Diego, CA 92123']},
#    'phone': '+18582773989',
#    'display_phone': '(858) 277-3989',
#    'distance': 4911.004822540456},
#   {'id': 'iczXD1EwZkPo9kAKKgKZlg',
#    'alias': 'shimbashi-izakaya-del-mar',
#    'name': 'Shimbashi Izakaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zylhoM6I0iXXkauF0lpUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shimbashi-izakaya-del-mar?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 430,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.9608496936452,
#     'longitude': -117.264980309856},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1555 Camino Del Mar',
#     'address2': 'Ste 201',
#     'address3': '',
#     'city': 'Del Mar',
#     'zip_code': '92014',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['1555 Camino Del Mar',
#      'Ste 201',
#      'Del Mar, CA 92014']},
#    'phone': '+18585230479',
#    'display_phone': '(858) 523-0479',
#    'distance': 21581.489835164102},
#   {'id': 'AMIUmmRIs7_TRhlGTwn3RQ',
#    'alias': 'ichiro-japanese-restaurant-san-diego-3',
#    'name': 'Ichiro Japanese Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rQgwjOrC2f1EuZXwZezNMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichiro-japanese-restaurant-san-diego-3?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 382,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.8197984749239,
#     'longitude': -117.155915454631},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '4344 Convoy St',
#     'address2': 'Ste Q',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92111',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['4344 Convoy St', 'Ste Q', 'San Diego, CA 92111']},
#    'phone': '+18585658603',
#    'display_phone': '(858) 565-8603',
#    'distance': 3254.629792578273},
#   {'id': 'O1NFJA0OI0-N77JzP7qlfQ',
#    'alias': 'azuki-sushi-san-diego-2',
#    'name': 'Azuki Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OhZXVgOO-hfWKNegZUh4wA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/azuki-sushi-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 2141,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 32.72964, 'longitude': -117.15999},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2321 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92101',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2321 5th Ave', 'San Diego, CA 92101']},
#    'phone': '+16192384760',
#    'display_phone': '(619) 238-4760',
#    'distance': 6815.994008391664},
#   {'id': 'E_QeIiXJdDGVYtu_WL9ARg',
#    'alias': 'ramen-ryoma-san-diego-2',
#    'name': 'Ramen Ryoma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/jVYaj6RhtW76FXBSsCKItA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-ryoma-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 148,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 32.79637, 'longitude': -117.25511},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '825 Garnet Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'San Diego',
#     'zip_code': '92109',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['825 Garnet Ave', 'San Diego, CA 92109']},
#    'phone': '+18584830177',
#    'display_phone': '(858) 483-0177',
#    'distance': 9425.848563058935},
#   {'id': 'TSYhYwOPeaZmRNuiJoZaAw',
#    'alias': 'soichi-sushi-san-diego-2',
#    'name': 'Soichi Sushi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lEyUC06-OUngjtN-lzzDxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/soichi-sushi-san-diego-2?adjust_creative=2hT8MEWNgk8G1aOCC6pfXA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=2hT8MEWNgk8G1aOCC6pfXA',
#    'review_count': 226,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 32.76267, 'longitude': -117.1418},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'location': {'address1': '2121 Adams Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'San Diego',
#     'zip_code': '92116',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['2121 Adams Ave', 'San Diego, CA 92116']},
#    'phone': '+16196772220',
#    'display_phone': '(619) 677-2220',
#    'distance': 3309.247570965769}],
#  'total': 100,
#  'region': {'center': {'longitude': -117.15408325195312,
#    'latitude': 32.790569394537286}}}
